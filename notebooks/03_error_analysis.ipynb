# %% [markdown]
# # Error Analysis

# %% [markdown]
# ## Stage A error inspection
# Look at coefficient stability and worst-predicted participants/clips for the EEG->self-report models.

# %% [markdown]
# ## Bridge error inspection
# Inspect bridge scatterplot outliers — check alignment_log.csv for possible audio-matching mistakes before concluding a clip is a genuine outlier.
